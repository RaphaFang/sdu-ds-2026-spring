# %% [markdown]
# 馬哈拉諾比斯距離則像是沿著數據的分佈畫同心橢圓。
# 它會將原本傾斜、拉伸的數據空間「擠壓且旋轉」成一個標準的圓形空間（類似於將數據做標準化 Z-score 的多維升級版）。
# 在這個空間裡計算出來的平方距離，就是 $D^2$

# %% [markdown]
# exp(x) = e to the power of x

# %% [markdown]
# x, y 是
# 是兩者uncoorelate
# 同時也是linear independent
